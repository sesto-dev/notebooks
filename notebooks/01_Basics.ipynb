# %%
import numpy as np
import pandas as pd
import MetaTrader5 as mt5
import statsmodels.api as sm
from statsmodels.tsa.stattools import coint, adfuller

import matplotlib.pyplot as plt
from backtester.data_handler import DataHandler

# %%
SYMBOLS = ["WTI", "BRN", 'USDJPY']
TIMEFRAME = mt5.TIMEFRAME_H1
BARS = 500

# %%
data_handler = DataHandler(SYMBOLS, TIMEFRAME, BARS)
data = data_handler.fetch_data()

# %%
for symbol, symbol_data in data.items():
    plt.figure(figsize=(10,6))
    plt.plot(symbol_data['close'])
    plt.title(f'{symbol} Close Price')
    plt.xlabel('Time')
    plt.ylabel('Price')
    plt.show()

# %%
# Create a figure and axis
fig, ax = plt.subplots(figsize=(10,6))

# Loop through shared.data and plot each line on the same chart
for symbol, data in meta.data.items():
    # Normalize the close column
    normalized_close = data['close'] / data['close'].max()
    
    # Plot the normalized line
    ax.plot(normalized_close, label=symbol)

# Add title, x-axis label, y-axis label, and legend
ax.set_title('Close Prices')
ax.set_xlabel('Time')
ax.set_ylabel('Price')
ax.legend()

# Show the figure
plt.show()
